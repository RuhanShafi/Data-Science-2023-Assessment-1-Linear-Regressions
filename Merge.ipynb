# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('fundamentals.csv')
df2 = pd.read_csv('prices-split-adjusted.csv')
df1 = df1.dropna()
df2 = df2.dropna()

# %%
df1.shape
# Out:
# (1299, 79)

# %%
df2.shape
# Out:
# (851264, 7)

# %%
df1= df1.rename(columns={'Period Ending': 'date'})

# %%
df1.head()
# Out:
#    Unnamed: 0 Ticker Symbol        date  Accounts Payable  \
# 0           0           AAL  2012-12-31      3.068000e+09
# 1           1           AAL  2013-12-31      4.975000e+09
# 2           2           AAL  2014-12-31      4.668000e+09
# 3           3           AAL  2015-12-31      5.102000e+09
# 4           4           AAP  2012-12-29      2.409453e+09
#
#    Accounts Receivable  Add'l income/expense items  After Tax ROE  \
# 0         -222000000.0               -1.961000e+09           23.0
# 1          -93000000.0               -2.723000e+09           67.0
# 2         -160000000.0               -1.500000e+08          143.0
# 3          352000000.0               -7.080000e+08          135.0
# 4          -89482000.0                6.000000e+05           32.0
#
#    Capital Expenditures  Capital Surplus  Cash Ratio  ...  \
# 0         -1.888000e+09     4.695000e+09        53.0  ...
# 1         -3.114000e+09     1.059200e+10        75.0  ...
# ...

# %%
df2.head()
# Out:
#          date symbol        open       close         low        high  \
# 0  2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000
# 1  2016-01-06   WLTW  125.239998  119.980003  119.940002  125.540001
# 2  2016-01-07   WLTW  116.379997  114.949997  114.930000  119.739998
# 3  2016-01-08   WLTW  115.480003  116.620003  113.500000  117.440002
# 4  2016-01-11   WLTW  117.010002  114.970001  114.089996  117.330002
#
#       volume
# 0  2163600.0
# 1  2386400.0
# 2  2489500.0
# 3  2006300.0
# 4  1408600.0

# %%
df = df2.merge(df1,on='date')
df = df.dropna()
df = df.sample(frac = 1)

# %%
df.head()
# Out:
#               date symbol       open      close        low       high  \
# 55936   2012-12-31    HCP  40.710386  41.129328  40.619307  41.147543
# 423894  2015-12-31    ETN  52.410000  52.040001  52.020000  52.790001
# 67310   2012-12-31    MCD  87.419998  88.209999  86.809998  88.250000
# 55540   2012-12-31   HBAN   6.250000   6.390000   6.250000   6.400000
# 192331  2013-12-31   NLSN  45.700001  45.889999  45.650002  46.200001
#
#            volume  Unnamed: 0 Ticker Symbol  Accounts Payable  ...  \
# 55936   2288000.0         306          CHRW      9.105550e+08  ...
# 423894  2080200.0        1155           NFX      6.320000e+08  ...
# 67310   6236600.0         298           CHD      4.718000e+08  ...
# 55540   6685600.0        1204           OKE      1.333489e+09  ...
# 192331  1297900.0        1104           MRO      3.891000e+09  ...
#
#         Total Current Assets  Total Current Liabilities  Total Equity  \
# ...

# %%
df.shape
# Out:
# (502263, 85)

# %%
df.to_csv('Merge_output.csv')
